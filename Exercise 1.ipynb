# %% [markdown]
# # Exercise 1: Getting Started
# ![image.png](attachment:image.png)

# %% [markdown]
# Follow the links to
#
# * [Download the FEniCS Tutorial](https://fenicsproject.org/tutorial/)
# * [Install FEniCS 2017.2](https://fenicsproject.org/download/)
#
# Note that you can create and run a FEniCS notebook on your local machine by using the `fenicsproject` script with the following commands:
#
#     fenicsproject notebook mynotebook
#     fenicsproject start mynotebook
#
# Once you have installed FEniCS, try the following commands to test your installation.
#
#     from fenics import *
#     mesh = UnitCubeMesh(8, 8, 8)
#     plot(mesh)
#
# You should see a plot of a unit cube mesh.

# %% [markdown]
# ## Initializing notebook plotting
#
# When running in a Jupyter notebook, the following line is necessary to show FEniCS plots in the notebook.

# %%
# %matplotlib inline

# %% [markdown]
# ## Testing the FEniCS installation
#
# Try the commands listed above. You should see a plot of a unit cube mesh.

# %%
from fenics import *

# %%
mesh = UnitCubeMesh(8, 8, 8)
plot(mesh)

# %%
# !tar cvfz allfiles.tar.gz *
# Out:
# Exercise 1.ipynb
# Exercise 2.ipynb
# Exercise 3.ipynb
# Exercise 4.ipynb
# Exercise 5a.ipynb
# Exercise 5b.ipynb
# Exercise 6.ipynb
# Exercise 7.ipynb
# Lectures/
# Lectures/lecture_05.pdf
# Lectures/lecture_01.pdf
# Lectures/lecture_03.pdf
# Lectures/lecture_06.pdf
# Lectures/lecture_02.pdf
# Lectures/lecture_04.pdf
# dolfin_coarse.xml.gz
